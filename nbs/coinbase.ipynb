# %%
#| default_exp coinbase

# %%
#|hide
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Coinbase
#
# Manages the coinbase data download and processing. It is important to note that the Coinbase API might change from time to time, and the functions might need to be updated. You can find the documentation here: https://docs.cdp.coinbase.com/exchange/reference/exchangerestapi_getproductcandles.
#
# Notice also that there are limits of what one can download. See the documentation for more details. In particular: https://docs.cdp.coinbase.com/exchange/docs/rest-rate-limits

# %%
#| export
from datetime import datetime
import pandas as pd
import requests
import os
import datetime as dt

# %%
#| export

def retrieve_coinbase_price(pair="BTC-USD",time_interval=3600, 
                            end_date=datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ'), 
                            start_date=(datetime.now()-pd.Timedelta(days=2)).strftime('%Y-%m-%dT%H:%M:%SZ')):
    # This function retrieves the price data from Coinbase for a given pair and time interval.
    # There is a limit of 300 requests per hour.
    # There is a maximum of 200 candles per request. If you need more, you need to paginate.
    # If you try to retrive more per hour or more candles per request, you will get a error, and the function will return None.
    # General URL is: https://api.exchange.coinbase.com/products/{pair}/candles
    # Important: time_interval is in seconds
    # For documentation see: https://docs.cdp.coinbase.com/exchange/reference/exchangerestapi_getproductcandles
    
    url = f"https://api.exchange.coinbase.com/products/{pair}/candles?granularity={time_interval}&start={start_date}&end={end_date}"
    response = requests.get(url)
    if response.status_code != 200:
        return None
    data = response.json()
    if not data:
        return None

    column_names = ['unix', 'low', 'high', 'open', 'close', 'volume']
    df = pd.DataFrame(data, columns=column_names)
    df['datetime'] = pd.to_datetime(df['unix'], unit='s')
    df['pair'] = pair
    df = df.sort_values(by='datetime')
    # drop unix column and put date first
    df = df.drop(columns=['unix'])
    df = df[['datetime'] + [col for col in df.columns if col != 'datetime']]
    return df

# %%
#| export

def coinbase_tokens():
    currencies_url = "https://api.exchange.coinbase.com/products"
    currencies_response = requests.get(currencies_url)
    currencies_data = currencies_response.json()
    return pd.DataFrame(currencies_data)

# %%
#| export
def coinbase_usd_tokens():
    tokens = coinbase_tokens()
    return tokens[tokens['quote_currency']=='USD']

# %%
#| export

# Download long time series from Coinbase accounting for maximum number of dates per request
def coinbase_price_history(pair='BTC-USD',start_date='2024-01-01',end_date='2024-05-01',time_interval=3600,max_pull=250,verbose=False):
    # This function downloads the price history for a given pair from Coinbase.
    # It accounts for the maximum number of dates that can be downloaded at once. This can change in the future.

    # convert the dates to datetime
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    if end_date < start_date:
        # raise an error
        raise ValueError("End date is smaller than start date")
    # calculate the number of hours between the start and end date
    n_hours = (end_date - start_date).days * 24
    if n_hours <= max_pull:
        df = retrieve_coinbase_price(pair,start_date=start_date.strftime('%Y-%m-%dT%H:%M:%SZ'),end_date=end_date.strftime('%Y-%m-%dT%H:%M:%SZ'),time_interval=time_interval)
        return df
    # create a timeline with the maximum number of dates per request
    time_line = pd.date_range(start=start_date, end=end_date, periods=n_hours//max_pull+1)
    price_list = []
    for i in range(len(time_line)-1):
        end = time_line[i+1]
        start = time_line[i]
        if verbose:
            print(f"Downloading data from {start} to {end}")
        df = retrieve_coinbase_price(pair,start_date=start.strftime('%Y-%m-%dT%H:%M:%SZ'),end_date=end.strftime('%Y-%m-%dT%H:%M:%SZ'),time_interval=time_interval)
        if df is not None:
            price_list.append(df)
    # concatenate the dataframes and sort by date and drop duplicates dates
    df = pd.concat(price_list)
    df = df.sort_values(by='datetime')
    df = df.drop_duplicates(subset='datetime').reset_index(drop=True)
    return df

# %%
#| export

def save_file(df,folder_path,file_name,type="csv"):
    if type == "csv":
        df.to_csv(f"{folder_path}/{file_name}.csv",index=False)
    elif type == "parquet":
        df.to_parquet(f"{folder_path}/{file_name}.parquet")

# %%
#| export

def coinbase_to_file(folder_path="../data/coinbase",token_list=coinbase_usd_tokens()['id'].tolist(),type="csv",
                     interval=3600,all_tokens=True):
    # Documentation:
    # This function downloads the price history for a given list of tokens from Coinbase and saves them in a folder.
    # If the folder does not exist, it creates it.
    # If the folder exists, it reads the existing files and appends the new data to them.
    # The files are saved in the folder with the name of the token and the extension of the type.
    # The files are saved in the format of the type.
    
    # create the folder if it does not exist, and if it exists, read the file names
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    else:
        if all_tokens:
            file_names = os.listdir(folder_path)
            # remove the file extension
            tokens_in_folder = [os.path.splitext(file_name)[0] for file_name in file_names]
            # join tokens in folder with token_list and remove the duplicates
            token_list = list(set(token_list + tokens_in_folder))
    # loop over the token list and open the file if it exists and append the new data
    for token in token_list:
        print(f"Processing {token}")
        file_name = f"{folder_path}/{token}.{type}"
        if os.path.exists(file_name):
            if type == "csv":
                df = pd.read_csv(file_name)
            elif type == "parquet":
                df = pd.read_parquet(file_name)
            else:
                raise ValueError(f"Type {type} not supported")
            # read last date in the file
            last_date = pd.to_datetime(df['datetime'].iloc[-1])
            if interval == 3600:
                today = datetime.now(tz=dt.UTC).replace(minute=0,second=0,microsecond=0)
            else:
                today = datetime.now(tz=dt.UTC)
            #print(last_date.tz_localize(dt.UTC),today)
            if last_date.tz_localize(dt.UTC) < today:
                df_new = coinbase_price_history(pair=token,
                                            start_date=last_date.strftime('%Y-%m-%dT%H:%M:%SZ'),
                                            end_date=today.strftime('%Y-%m-%dT%H:%M:%SZ'),
                                            time_interval=interval)
                df = pd.concat([df,df_new])
                # drop duplicates and sort by date
                df = df.drop_duplicates(subset='datetime').sort_values(by='datetime').reset_index(drop=True)
                save_file(df,folder_path,token,type)
            else:
                print(f"File {token} is up to date")
        else:
            df = coinbase_price_history(pair=token,
                                        start_date='2016-01-01T00:00:00Z',
                                        end_date=datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ'),
                                        time_interval=interval)
            save_file(df,folder_path,token,type)

# %%
#| export
def read_all_files(folder_path="../data/coinbase",type="csv"):
    file_names = os.listdir(folder_path)
    df_list = []
    for file_name in file_names:
        if type == "csv":
            df = pd.read_csv(f"{folder_path}/{file_name}")
        elif type == "parquet":
            df = pd.read_parquet(f"{folder_path}/{file_name}")
        else:
            raise ValueError(f"Type {type} not supported")
        df_list.append(df)
    return pd.concat(df_list)

# %% [markdown]
# ## Examples

# %% [markdown]
# List the available tokens on Coinbase.

# %%
#| eval: false
tokens = coinbase_tokens()
print(tokens)
# Out:
#                 id base_currency quote_currency quote_increment  \
# 0          LTC-GBP           LTC            GBP            0.01
# 1          UMA-EUR           UMA            EUR           0.001
# 2         IOTX-EUR          IOTX            EUR         0.00001
# 3          VGX-EUR           VGX            EUR          0.0001
# 4      BIGTIME-USD       BIGTIME            USD         0.00001
# ..             ...           ...            ...             ...
# 641       ZEN-USDT           ZEN           USDT            0.01
# 642      1INCH-BTC         1INCH            BTC       0.0000001
# 643        JTO-USD           JTO            USD          0.0001
# 644      NEST-USDT          NEST           USDT         0.00001
# 645  CORECHAIN-USD     CORECHAIN            USD           0.001
#
#     base_increment   display_name min_market_funds  margin_enabled  post_only  \
# 0       0.00000001        LTC-GBP             0.72           False      False
# 1            0.001        UMA-EUR             0.84           False      False
# 2                1       IOTX-EUR             0.84           False      False
# 3             0.01        VGX-EUR             0.84           False      False
# 4                1    BIGTIME-USD                1           False      False
# ..             ...            ...              ...             ...        ...
# 641          0.001       ZEN-USDT                1           False      False
# 642           0.01      1INCH-BTC         0.000016           False      False
# 643            0.1        JTO-USD                1           False      False
# 644              1      NEST-USDT                1           False      False
# 645           0.01  CORECHAIN/USD                1           False      False
#
#      limit_only  cancel_only    status status_message  trading_disabled  \
# 0         False        False    online                            False
# 1         False        False  delisted                             True
# 2         False        False  delisted                             True
# 3         False        False  delisted                             True
# 4         False        False    online                            False
# ..          ...          ...       ...            ...               ...
# 641       False        False  delisted                             True
# 642       False        False    online                            False
# 643       False        False    online                            False
# 644       False        False  delisted                             True
# 645       False        False    online                            False
#
#      fx_stablecoin max_slippage_percentage  auction_mode  \
# 0            False              0.03000000         False
# 1            False              0.03000000         False
# 2            False              0.03000000         False
# 3            False              0.03000000         False
# 4            False              0.03000000         False
# ..             ...                     ...           ...
# 641          False              0.03000000         False
# 642          False              0.03000000         False
# 643          False              0.03000000         False
# 644          False              0.03000000         False
# 645          False              0.03000000         False
#
#     high_bid_limit_percentage
# 0
# 1
# 2
# 3
# 4
# ..                        ...
# 641
# 642
# 643
# 644
# 645
#
# [646 rows x 18 columns]

# %% [markdown]
# To make it simpler, we can filter the tokens by the quote currency. In this case, we filter for USD.

# %%
#| eval: false
usd_tokens = coinbase_usd_tokens()
print(usd_tokens)
# Out:
#              id base_currency quote_currency quote_increment base_increment  \
# 0    PIRATE-USD        PIRATE            USD          0.0001            0.1
# 5       DOT-USD           DOT            USD           0.001     0.00000001
# 6    AURORA-USD        AURORA            USD           0.001           0.01
# 7       UPI-USD           UPI            USD         0.00001              1
# 8      OMNI-USD          OMNI            USD           0.001           0.01
# ..          ...           ...            ...             ...            ...
# 640    RARI-USD          RARI            USD            0.01          0.001
# 641   SUPER-USD         SUPER            USD         0.00001           0.01
# 642    HIGH-USD          HIGH            USD           0.001           0.01
# 644     TRB-USD           TRB            USD            0.01          0.001
# 645     DNT-USD           DNT            USD          0.0001            0.1
#
#     display_name min_market_funds  margin_enabled  post_only  limit_only  \
# 0     PIRATE/USD                1           False      False       False
# 5        DOT-USD                1           False      False       False
# 6     AURORA-USD                1           False      False       False
# 7        UPI-USD                1           False      False       False
# 8       OMNI/USD                1           False      False       False
# ..           ...              ...             ...        ...         ...
# 640     RARI-USD                1           False      False       False
# 641    SUPER-USD                1           False      False       False
# 642     HIGH-USD                1           False      False       False
# 644      TRB-USD                1           False      False       False
# 645      DNT-USD                1           False      False       False
#
#      cancel_only    status status_message  trading_disabled  fx_stablecoin  \
# 0          False    online                            False          False
# 5          False    online                            False          False
# 6          False    online                            False          False
# 7          False  delisted                             True          False
# 8          False    online                            False          False
# ..           ...       ...            ...               ...            ...
# 640        False    online                            False          False
# 641        False    online                            False          False
# 642        False    online                            False          False
# 644        False    online                            False          False
# 645        False    online                            False          False
#
#     max_slippage_percentage  auction_mode high_bid_limit_percentage
# 0                0.03000000         False
# 5                0.03000000         False
# 6                0.03000000         False
# 7                0.03000000         False
# 8                0.03000000         False
# ..                      ...           ...                       ...
# 640              0.03000000         False
# 641              0.03000000         False
# 642              0.03000000         False
# 644              0.03000000         False
# 645              0.05000000         False
#
# [307 rows x 18 columns]

# %% [markdown]
# Download the historical price of BTC-USD for few months at every hour. IMPORTANT: datetime is in UTC!

# %%
#| eval: false
df = coinbase_price_history()
print(df)
# Out:
#                 datetime       low      high      open     close       volume  \
# 0    2024-01-01 00:00:00  42261.58  42543.64  42288.58  42452.66   379.197253
# 1    2024-01-01 01:00:00  42415.00  42749.99  42453.83  42594.68   396.201924
# 2    2024-01-01 02:00:00  42488.03  42625.68  42594.58  42571.32   227.141166
# 3    2024-01-01 03:00:00  42235.00  42581.26  42571.32  42325.11   306.005694
# 4    2024-01-01 04:00:00  42200.00  42393.48  42325.10  42389.77   296.233644
# ...                  ...       ...       ...       ...       ...          ...
# 2900 2024-04-30 20:00:00  59087.36  60082.82  59098.18  59869.99  1655.908771
# 2901 2024-04-30 21:00:00  59862.17  60326.56  59865.66  60100.36   615.103455
# 2902 2024-04-30 22:00:00  60070.00  60990.48  60100.01  60526.64   727.224395
# 2903 2024-04-30 23:00:00  60330.92  60878.39  60529.65  60622.10   346.354179
# 2904 2024-05-01 00:00:00  60015.99  60785.49  60621.20  60173.03   499.935743
#
#          pair
# 0     BTC-USD
# 1     BTC-USD
# 2     BTC-USD
# 3     BTC-USD
# 4     BTC-USD
# ...       ...
# 2900  BTC-USD
# 2901  BTC-USD
# 2902  BTC-USD
# 2903  BTC-USD
# 2904  BTC-USD
#
# [2905 rows x 7 columns]

# %% [markdown]
# Download all history available in coinbase for the tokens saved in folder "../data/coinbase"
# This process can take a while specially if you are downloading many tokens the first time.

# %%
#| eval: false
coinbase_to_file(token_list=['OP-USD'],type="parquet")
# Out:
# Processing OP-USD
# File OP-USD is up to date
# Processing AAVE-USD
# File AAVE-USD is up to date

# %% [markdown]
# Now read the file from folder "../data/coinbase":

# %%
#| eval: false
df = pd.read_parquet("../data/coinbase/AAVE-USD.parquet")
print(df)
# Out:
#                  datetime      low     high     open    close    volume  \
# 0     2020-12-15 17:00:00   87.700   90.400   90.400   88.347  4289.548
# 1     2020-12-15 18:00:00   85.620   88.407   88.010   86.000  3802.529
# 2     2020-12-15 19:00:00   84.575   89.500   86.105   85.952  2835.124
# 3     2020-12-15 20:00:00   84.828   85.952   85.952   85.599   798.670
# 4     2020-12-15 21:00:00   84.744   85.893   85.599   85.208   442.464
# ...                   ...      ...      ...      ...      ...       ...
# 34263 2024-11-12 13:00:00  172.640  177.580  177.420  176.540  4893.095
# 34264 2024-11-12 14:00:00  175.430  180.380  176.640  180.260  4112.704
# 34265 2024-11-12 15:00:00  177.400  180.860  180.160  177.450  6045.649
# 34266 2024-11-12 16:00:00  174.740  178.960  177.460  178.530  4194.807
# 34267 2024-11-12 17:00:00  178.200  179.230  178.980  178.850   383.705
#
#            pair
# 0      AAVE-USD
# 1      AAVE-USD
# 2      AAVE-USD
# 3      AAVE-USD
# 4      AAVE-USD
# ...         ...
# 34263  AAVE-USD
# 34264  AAVE-USD
# 34265  AAVE-USD
# 34266  AAVE-USD
# 34267  AAVE-USD
#
# [34268 rows x 7 columns]

# %% [markdown]
# Full download with no files in the folder takes almost 5 hours. After that, it is much faster (~ 6 minutes).

# %%
#| eval: false
coinbase_to_file(type="parquet") # takes almost 5 hours if there no files in the folder!
# Out:
# Processing ATOM-USD
# Processing DYP-USD
# Processing ASM-USD
# Processing ENJ-USD
# Processing RAD-USD
# Processing COMP-USD
# Processing ZK-USD
# Processing ZETA-USD
# Processing FET-USD
# Processing RPL-USD
# Processing OP-USD
# File OP-USD is up to date
# Processing HBAR-USD
# Processing INJ-USD
# Processing DDX-USD
# Processing 1INCH-USD
# Processing TRIBE-USD
# Processing LRC-USD
# Processing MLN-USD
# Processing AAVE-USD
# File AAVE-USD is up to date
# Processing POL-USD
# Processing GRT-USD
# Processing MATIC-USD
# Processing GST-USD
# Processing WCFG-USD
# Processing C98-USD
# Processing BNT-USD
# Processing MPL-USD
# Processing BLAST-USD
# Processing BLZ-USD
# Processing PRIME-USD
# Processing UMA-USD
# Processing EGLD-USD
# Processing DAI-USD
# Processing MDT-USD
# Processing RNDR-USD
# Processing COVAL-USD
# Processing OOKI-USD
# Processing LIT-USD
# Processing MSOL-USD
# Processing MATH-USD
# Processing RGT-USD
# Processing MULTI-USD
# Processing UNI-USD
# Processing TONE-USD
# Processing ANT-USD
# Processing GHST-USD
# Processing SUI-USD
# Processing DREP-USD
# Processing NEON-USD
# Processing MANA-USD
# Processing CTX-USD
# Processing PNG-USD
# Processing AKT-USD
# Processing CORECHAIN-USD
# Processing SWFTC-USD
# Processing BIGTIME-USD
# Processing DAR-USD
# Processing OMNI-USD
# Processing DOT-USD
# Processing AST-USD
# Processing OSMO-USD
# Processing GODS-USD
# Processing OGN-USD
# Processing PYR-USD
# Processing CVC-USD
# Processing NCT-USD
# Processing JASMY-USD
# Processing BADGER-USD
# Processing ABT-USD
# Processing QNT-USD
# Processing JTO-USD
# Processing MOBILE-USD
# Processing OXT-USD
# Processing AVAX-USD
# Processing OCEAN-USD
# Processing QI-USD
# Processing FARM-USD
# Processing PAX-USD
# Processing IDEX-USD
# Processing CHZ-USD
# Processing ZEC-USD
# Processing BAT-USD
# Processing WAMPL-USD
# Processing MAGIC-USD
# Processing FLR-USD
# Processing TRB-USD
# Processing HONEY-USD
# Processing BTRST-USD
# Processing HOPR-USD
# Processing DASH-USD
# Processing SUPER-USD
# Processing GALA-USD
# Processing SPA-USD
# Processing RBN-USD
# Processing YFII-USD
# Processing HNT-USD
# Processing XRP-USD
# Processing HIGH-USD
# Processing VOXEL-USD
# Processing MXC-USD
# Processing FORT-USD
# Processing AUCTION-USD
# Processing SKL-USD
# Processing AIOZ-USD
# Processing BUSD-USD
# Processing HFT-USD
# Processing GTC-USD
# Processing INDEX-USD
# Processing BOND-USD
# Processing ZEN-USD
# Processing CRPT-USD
# Processing SAND-USD
# Processing SEI-USD
# Processing MONA-USD
# Processing AMP-USD
# Processing MIR-USD
# Processing RENDER-USD
# Processing YFI-USD
# Processing LDO-USD
# Processing ZRX-USD
# Processing KNC-USD
# Processing RAI-USD
# Processing FIL-USD
# Processing FOX-USD
# Processing MKR-USD
# Processing PERP-USD
# Processing ALEO-USD
# Processing MNDE-USD
# Processing ALEPH-USD
# Processing ALCX-USD
# Processing CTSI-USD
# Processing 00-USD
# Processing VGX-USD
# Processing LOKA-USD
# Processing BTC-USD
# Processing RLC-USD
# Processing FIS-USD
# Processing TIME-USD
# Processing WLUNA-USD
# Processing XYO-USD
# Processing IO-USD
# Processing VTHO-USD
# Processing MUSE-USD
# Processing FORTH-USD
# Processing IMX-USD
# Processing FX-USD
# Processing SNT-USD
# Processing STG-USD
# Processing POWR-USD
# Processing VELO-USD
# Processing FIDA-USD
# Processing POND-USD
# Processing SPELL-USD
# Processing BICO-USD
# Processing RARI-USD
# Processing VET-USD
# Processing SOL-USD
# Processing XLM-USD
# Processing DNT-USD
# Processing BCH-USD
# Processing DRIFT-USD
# Processing API3-USD
# Processing GAL-USD
# Processing KAVA-USD
# Processing NEAR-USD
# Processing TRAC-USD
# Processing ELA-USD
# Processing ORN-USD
# Processing XTZ-USD
# Processing APT-USD
# Processing NKN-USD
# Processing ORCA-USD
# Processing LOOM-USD
# Processing ACS-USD
# Processing PUNDIX-USD
# Processing WBTC-USD
# Processing RLY-USD
# Processing ZETACHAIN-USD
# Processing AERGO-USD
# Processing REQ-USD
# Processing GNO-USD
# Processing EIGEN-USD
# Processing LINK-USD
# Processing ATA-USD
# Processing KEEP-USD
# Processing MINA-USD
# Processing DOGE-USD
# Processing ALICE-USD
# Processing BAND-USD
# Processing AXL-USD
# Processing SWELL-USD
# Processing KRL-USD
# Processing TIA-USD
# Processing POLY-USD
# Processing CBETH-USD
# Processing CLV-USD
# Processing ILV-USD
# Processing LQTY-USD
# Processing REN-USD
# Processing SHDW-USD
# Processing FLOW-USD
# Processing ROSE-USD
# Processing AVT-USD
# Processing SHPING-USD
# Processing QSP-USD
# Processing SHIB-USD
# Processing EOS-USD
# Processing ALGO-USD
# Processing METIS-USD
# Processing XCN-USD
# Processing OMG-USD
# Processing STX-USD
# Processing CELR-USD
# Processing G-USD
# Processing ACX-USD
# Processing ADA-USD
# Processing UNFI-USD
# Processing GMT-USD
# Processing SUSHI-USD
# Processing NMR-USD
# Processing SEAM-USD
# Processing RARE-USD
# Processing AERO-USD
# Processing COW-USD
# Processing CRO-USD
# Processing LCX-USD
# Processing KARRAT-USD
# Processing DEGEN-USD
# Processing QUICK-USD
# Processing EURC-USD
# Processing SYN-USD
# Processing APE-USD
# Processing PRQ-USD
# Processing T-USD
# Processing AURORA-USD
# Processing MEDIA-USD
# Processing REP-USD
# Processing PYUSD-USD
# Processing PIRATE-USD
# Processing POLS-USD
# Processing USDT-USD
# Processing MTL-USD
# Processing JUP-USD
# Processing NU-USD
# Processing LRDS-USD
# Processing GLM-USD
# Processing MUSD-USD
# Processing DEXT-USD
# Processing TVK-USD
# Processing ANKR-USD
# Processing PLA-USD
# Processing CVX-USD
# Processing GUSD-USD
# Processing CGLD-USD
# Processing GYEN-USD
# Processing DESO-USD
# Processing RONIN-USD
# Processing DIA-USD
# Processing SUKU-USD
# Processing IOTX-USD
# Processing ARB-USD
# Processing ETH-USD
# Processing A8-USD
# Processing MASK-USD
# Processing GFI-USD
# Processing KSM-USD
# Processing PLU-USD
# Processing UST-USD
# Processing AGLD-USD
# Processing ETC-USD
# Processing ERN-USD
# Processing PRO-USD
# Processing UPI-USD
# Processing LTC-USD
# Processing BAL-USD
# Processing ONDO-USD
# Processing STRK-USD
# Processing BONK-USD
# Processing ARPA-USD
# Processing AXS-USD
# Processing ACH-USD
# Processing ENS-USD
# Processing LPT-USD
# Processing CRV-USD
# Processing ZRO-USD
# Processing BIT-USD
# Processing TRU-USD
# Processing AUDIO-USD
# Processing ARKM-USD
# Processing INV-USD
# Processing TNSR-USD
# Processing SAFE-USD
# Processing SYLO-USD
# Processing DIMO-USD
# Processing WAXL-USD
# Processing VARA-USD
# Processing SD-USD
# Processing BLUR-USD
# Processing SNX-USD
# Processing WELL-USD
# Processing BOBA-USD
# Processing LSETH-USD
# Processing MCO2-USD
# Processing ICP-USD
# Processing NEST-USD
# Processing COTI-USD
# Processing STORJ-USD

# %% [markdown]
# Read all files in the folder into a single dataframe:

# %%
#| eval: false
df = read_all_files(type="parquet")
print(df)
